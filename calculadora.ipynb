# %%
import calc as cl

# %%
op = int(input("Digite a operação desejada: 1-Soma, 2-Subtrair, 3-Multiplicar, 4-Dividir, 5-Potenciação, 6-Radiciação: "))

if op == 1:
    num1 = int(input("Digite o primeiro número: "))
    num2 = int(input("Digite o segundo número: "))
    print(cl.soma(num1, num2))

elif op ==2:
    num1 = int(input("Digite o primeiro número: "))
    num2 = int(input("Digite o segundo número: "))
    print(cl.subtracao(num1, num2))

elif op ==3:
    num1 = int(input("Digite o primeiro número: "))
    num2 = int(input("Digite o segundo número: "))
    print(cl.multpiplicacao(num1, num2))

elif op ==4:
    num1 = int(input("Digite o primeiro número: "))
    num2 = int(input("Digite o segundo número: "))
    print(cl.divisao(num1, num2))

elif op ==5:
    num1 = int(input("Digite o primeiro número: "))
    num2 = int(input("Digite o segundo número: "))
    print(cl.potencia(num1, num2))

elif op == 6:
    num1 = int(input("Digite o número: "))
    print(cl.raiz(num1))

else:
    print("Opção inválida!")
# Out:
# (1, 5)
